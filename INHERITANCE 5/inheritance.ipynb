# %% [markdown]
# ### Inheritance

# %% [markdown]
# 1.parent class
# 2.child class
# 3.child class will inhrit(attributes and function)from parent class

# %% [markdown]
# #### ![image.png](attachment:image.png)

# %%
class Person:

    def __init__(self, name:str, age:int) -> None:
        self.name = name
        self.age = age

    def introduce(self) -> None:
            print(f"My name is {self.name}")
            print(f"I am {self.age} years old")

# %%
class Employee(Person):

    def __init__(self, name:str,age:int, company:str) -> None:
        super().__init__(name, age)
        self.company = company

    def work(self) -> None:
            print(f" i work for {self.company}")

# %%
P1 = Person(name="seema",age=23)
type(P1)
# Out:
# __main__.Person

# %%
P1.name
# Out:
# 'seema'

# %%
P1.age
# Out:
# 23

# %%
P1.introduce()
# Out:
# My name is seema
# I am 23 years old

# %%
e1 = Employee(name="Raman", age=35, company="Infosys")
type(e1)
# Out:
# __main__.Employee

# %%
e1.name
# Out:
# 'Raman'

# %%
e1.age
# Out:
# 35

# %%
e1.company
# Out:
# 'Infosys'

# %%
e1.introduce()
# Out:
# My name is Raman
# I am 35 years old

# %%
e1.work()
# Out:
#  i work for Infosys

# %%
e1.introduce()
e1.work()
# Out:
# My name is Raman
# I am 35 years old
#  i work for Infosys

# %%
e1

# %%
P1

# %% [markdown]
# ### practical application of Inheritance

# %%
# %pip install pydantic email-validator
# Out:
# Requirement already satisfied: pydantic in c:\users\madan\onedrive\desktop\python.advanceu\repository\venv\lib\site-packages (2.10.2)
# Requirement already satisfied: email-validator in c:\users\madan\onedrive\desktop\python.advanceu\repository\venv\lib\site-packages (2.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\madan\onedrive\desktop\python.advanceu\repository\venv\lib\site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\madan\onedrive\desktop\python.advanceu\repository\venv\lib\site-packages (from pydantic) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\madan\onedrive\desktop\python.advanceu\repository\venv\lib\site-packages (from pydantic) (4.12.2)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\madan\onedrive\desktop\python.advanceu\repository\venv\lib\site-packages (from email-validator) (2.7.0)
# Requirement already satisfied: idna>=2.0.0 in c:\users\madan\onedrive\desktop\python.advanceu\repository\venv\lib\site-packages (from email-validator) (3.10)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Abrreviations

# %% [markdown]
# 1.gt-greater than
# 2.ge - greater than or equal to
# 3.It - less than
# 4.le -less than or equal to

# %%
from pydantic import BaseModel, Field, EmailStr
from typing import Literal, List

# %%
class Student(BaseModel):

    roll_no: int = Field(description="Student Roll number", gt=0)
    name: str = Field(description="Student Name", min_length=3, max_length=50)
    marks: float = Field(description="Student Marks", gt=0, lt=100)
    email: EmailStr = Field(description="Student Email", max_length=60)
    gender: Literal["male", "female"] = Field(description="Student Gender")
    hobbies: List[str] = Field(description="Student hobbies", default_factory=list)

    def student_info(self):
        print(f"Roll Number : {self.roll_no}")
        print(f"Name : {self.name}")
        print(f"Marks : {self.marks:.2f}")
        print(f"Email : {self.email}")
        print(f"Gender : {self.gender}")
        print(f"Hobbies : {self.hobbies}")

# %%
s1 = Student(
    roll_no=101,
    name="Aditi",
    marks=87.3,
    email="aditi@test.com",
    gender="female",
    hobbies=["Singing", "Cycling"],
)

# %%
s1
# Out:
# Student(roll_no=101, name='Aditi', marks=87.3, email='aditi@test.com', gender='female', hobbies=['Singing', 'Cycling'])

# %%
type(s1)
# Out:
# __main__.Student

# %%
s1.roll_no
# Out:
# 101

# %%
s1.name
# Out:
# 'Aditi'

# %%
s1.marks
# Out:
# 87.3

# %%
s1.email
# Out:
# 'aditi@test.com'

# %%
s1.gender
# Out:
# 'female'

# %%
s1.hobbies
# Out:
# ['Singing', 'Cycling']

# %%
s1.student_info()
# Out:
# Roll Number : 101
# Name : Aditi
# Marks : 87.30
# Email : aditi@test.com
# Gender : female
# Hobbies : ['Singing', 'Cycling']

# %%
s2 = Student(
    roll_no= "Twenty Two",
    name = 123,
    email = "email",
    gender = "Tcs",
    hobbies = (1, 2, 3 )
)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 s2 = Student(
#       2     roll_no= "Twenty Two",
#       3     name = 123,
#       4     email = "email",
#       5     gender = "Tcs",
#       6     hobbies = (1, 2, 3 )
#       7 )
#
# File c:\Users\madan\OneDrive\Desktop\python.advanceu\repository\venv\Lib\site-packages\pydantic\main.py:214, in BaseModel.__init__(self, **data)
#     212 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     213 __tracebackhide__ = True
# --> 214 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     215 if self is not validated_self:
#     216     warnings.warn(
#     217         'A custom validator is returning a value other than `self`.\n'
#     218         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     219         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     220         stacklevel=2,
#     221     )
#
# ValidationError: 8 validation errors for Student
# roll_no
#   Input should be a valid integer, unable to parse string as an integer [type=int_parsing, input_value='Twenty Two', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/int_parsing
# name
#   Input should be a valid string [type=string_type, input_value=123, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# marks
#   Field required [type=missing, input_value={'roll_no': 'Twenty Two',...', 'hobbies': (1, 2, 3)}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
# email
#   value is not a valid email address: An email address must have an @-sign. [type=value_error, input_value='email', input_type=str]
# gender
#   Input should be 'male' or 'female' [type=literal_error, input_value='Tcs', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/literal_error
# hobbies.0
#   Input should be a valid string [type=string_type, input_value=1, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# hobbies.1
#   Input should be a valid string [type=string_type, input_value=2, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type
# hobbies.2
#   Input should be a valid string [type=string_type, input_value=3, input_type=int]
#     For further information visit https://errors.pydantic.dev/2.10/v/string_type

# %%
s2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 s2
#
# NameError: name 's2' is not defined

# %%
s2 = Student(
    roll_no=101,
    name = "Raman",
    marks = 45.7,
    email = "random",
    gender = "male",
    hobbies = ["Cricket"]
)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 s2 = Student(
#       2     roll_no=101,
#       3     name = "Raman",
#       4     marks = 45.7,
#       5     email = "random",
#       6     gender = "male",
#       7     hobbies = ["Cricket"]
#       8 )
#
# File c:\Users\madan\OneDrive\Desktop\python.advanceu\repository\venv\Lib\site-packages\pydantic\main.py:214, in BaseModel.__init__(self, **data)
#     212 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     213 __tracebackhide__ = True
# --> 214 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     215 if self is not validated_self:
#     216     warnings.warn(
#     217         'A custom validator is returning a value other than `self`.\n'
#     218         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     219         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     220         stacklevel=2,
#     221     )
#
# ValidationError: 1 validation error for Student
# email
#   value is not a valid email address: An email address must have an @-sign. [type=value_error, input_value='random', input_type=str]

# %%
s2 = Student(
    roll_no=101,
    name = "Raman",
    marks=45.7,
    email = "raman@gmail.com",
    gender = "male",
    hobbies = ["Cricket"]

)

# %%
s2
# Out:
# Student(roll_no=101, name='Raman', marks=45.7, email='raman@gmail.com', gender='male', hobbies=['Cricket'])

# %%
s2.name
# Out:
# 'Raman'

# %%
s2.student_info()
# Out:
# Roll Number : 101
# Name : Raman
# Marks : 45.70
# Email : raman@gmail.com
# Gender : male
# Hobbies : ['Cricket']

# %% [markdown]
# ### Multilevel inheritance

# %% [markdown]
# 1.1 parent class
# 2. 2 child class
# 3. many grand child classes

# %%
class Employee2:

    def __init__(self, emp_id: int, name:str) -> None:
        self.emp_id = emp_id
        self.name = name

    def empoyee_info(self) -> None:
         print(f"Employee Id : {self.emp_id}")
         print(f"Name:{self.name}")

# %%
class Manager(Employee2):

    def __init__(self, emp_id: int, name: str, dept: str) -> None:
        super().__init__(emp_id, name)
        self.dept = dept

    def manager_info(self) -> None:
            print(f"Department : {self.dept}")

# %%
class ProjectManager(Manager):

    def __init__(self, emp_id: int, name: str,dept: str, project: str) -> None:
        super().__init__(emp_id, name, dept)
        self.project = project

    def get_project_info(self) -> None:
        print(f"Project name : {self.project}")

# %%
e1 = Employee2(emp_id=105, name="Suresh")
type(e1)
# Out:
# __main__.Employee2

# %%
e1.emp_id
# Out:
# 105

# %%
e1.name
# Out:
# 'Suresh'

# %%
e1.employee_info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[178], line 1
# ----> 1 e1.employee_info()
#
# AttributeError: 'Employee2' object has no attribute 'employee_info'
